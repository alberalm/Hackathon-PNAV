# %%
import geopandas as gpd
import pandas as pd
import os
import fiona

# %%
carpeta_principal = r"C:\Users\maria.b.calvo\Documents\Personal\Hackathon GenAI\hackathon-repo\Hackathon-PNAV\Datos\Datos Rutas"
archivos_a_excluir = ["CCNN_PTOSINTERES.shp"]

# %%
gdf_list = []
for raiz, _, archivos in os.walk(carpeta_principal):
    for archivo in archivos:
        ruta_completa = os.path.join(raiz, archivo)

        # Ignorar archivos específicos
        if archivo in archivos_a_excluir:
            print(f"Ignorando archivo: {archivo}")
            continue  

        # Leer archivos SHP
        if archivo.endswith(".shp"):
            try:
                gdf = gpd.read_file(ruta_completa)
                
                # Convertir CRS si es diferente
                if gdf.crs and gdf.crs.to_string() != "EPSG:4326":
                    gdf = gdf.to_crs("EPSG:4326")
                
                gdf["source"] = ruta_completa
                gdf_list.append(gdf)
            except Exception as e:
                print(f"Error al leer {ruta_completa}: {e}")

        # Leer archivos KML
        elif archivo.endswith(".kml"):
            try:
                # Obtener la lista de capas en el archivo KML
                layers = fiona.listlayers(ruta_completa)
                print(layers)
                
                # Intentar encontrar la capa que más se parece al nombre del archivo
                expected_layer = archivo[:-4]  # Nombre esperado
                matched_layer = None
                
                for layer in layers:
                    if expected_layer in layer:
                        matched_layer = layer
                        break
                
                if matched_layer is None:
                    print(f"No se encontró una capa coincidente en {ruta_completa}, usando la primera disponible.")
                    matched_layer = layers[0]  # Usar la primera capa si no hay coincidencias

                # Leer el archivo KML con la capa correcta
                gdf = gpd.read_file(ruta_completa, driver='KML', layer=matched_layer)

                # Convertir CRS si es diferente
                if gdf.crs and gdf.crs.to_string() != "EPSG:4326":
                    gdf = gdf.to_crs("EPSG:4326")

                gdf["source"] = ruta_completa
                gdf_list.append(gdf)

            except Exception as e:
                print(f"Error al leer {ruta_completa}: {e}")
# Out:
# Ignorando archivo: CCNN_PTOSINTERES.shp
# ['1-100-SA23-SA_Monte_Perdido']
# ['1-101-SA4-SA_Faja_Pardina']
# ['1-102-SP12-SP_Las_Cutas']
# ['1-103-SP11-SP_La_Escala_y_Cobatar']
# ['1-104-SA14-SA_Faja_Cazcarra']
# ['1-105-SP13-SP_Torla_a_Fanlo_por_los_miradores_del_Molar_y_el_barranco_Borrue']
# ['1-106-SA27-SA_Marbore', 'Ramales']
# ['1-107-SP14-SP_Valle_Pineta_Solana']
# ['1-108-SA7-SA_Bestue', 'Ramales']
# ['1-109-SA12-SA_Foratarruego']
# ['1-332-SA32-SA_Faja_de_las_Flores']
# ['1-333-SP17-SP_Puerto_Bujaruelo']
# ['1-397-SP7-SP12-Enlace_SP_Puerto_de_Fanlo_-_SP_Las_Cutas']
# ['1-56-SA9-SA_Buerba_a_Vio']
# ['1-57-SP10-SP_Miradores_de_Revilla']
# ['1-58-SA13-SA_Fuentes_del_Yaga']
# ['1-59-SA24-SA_Soaso_a_Goriz']
# ['1-60-SA29-SA_Puerto_de_Lera']
# ['1-61-SA20-SA_Turieto', 'Ramales']
# ['1-62-SP3-SP_Sestrales']
# ['1-63-SA18-SA_Carriata']
# ['1-65-SA22-SA_Cuello_Gordo', 'Ramales']
# ['1-66-SIA1-SIA_San_Urbez_al_Molino_de_Aso']
# ['1-67-SA2-SA_Arrablo']
# ['1-68-SP4-SP_Fanlo_a_Sercue_por_Nerin']
# ['1-69-SA21-SA_Faja_Pelay']
# ['1-70-SA10-SA_La_Valle']
# ['1-71-SP8-SP_Puerto_de_Buisan']
# ['1-72-SIA5-SIA_Parador_de_Ordesa']
# ['1-73-SP6-SP_Lomar']
# ['1-74-SP9-SP_Plana_Canal']
# ['1-75-SA30-SA_Tucarroya_a_Astazus', 'Ramales']
# ['1-76-SIA6-SIA_La_Larri_por_pista_y_ramal_Cascadas_de_La_Larri', 'Ramales']
# ['1-77-SA28-SA_Faja_Tormosa']
# ['1-78-SA11-SA_Bocera-Paraiso']
# ['1-79-SA16-SA_Faja_Canarellos']
# ['1-80-SIA3-SIA_Ermitas_de_Tella', 'Ramales']
# ['1-81-SA31-SA_Casa_dero_Puerto_a_la_Estiva', 'Ramales']
# ['1-82-SA8-SA_Faja_de_las_Olas']
# ['1-83-SA3-SA_Barranco_Pardina']
# ['1-84-SP1-SP_Bestue_a_Escuain']
# ['1-85-SA25-SA_Senda_de_los_Cazadores']
# ['1-86-SP16-SP_Selva_Pochas']
# ['1-87-SA17-SA_Cotatuero']
# ['1-88-SA26-SA_Collado_de_Anisclo']
# ['1-89-SP7-SP_Puerto_de_Fanlo']
# ['1-90-SA6-SA_Sercue']
# ['1-91-SP2-SP_Gallisue_a_Vio_y_Buerba', 'Ramales']
# ['1-92-SA15-SA_Faja_Racon']
# ['1-93-SA19-SA_Brecha_Rolando']
# ['1-94-SP15-SP_Valle_Pineta_Umbria']
# ['1-95-SP5-SP_Mondoto']
# ['1-96-SIA4-SIA_Soaso']
# ['1-97-SA1-SA_Anisclo']
# ['1-98-SA5-SA_Superior_de_Anisclo']
# ['1-99-SIA2-SIA_O_Castiello']
# ['10-247-3-Boqueron_del_Estena']
# ['10-248-5-Macizo_de_Rocigalgo']
# ['10-249-2-Plaza_de_los_Moros']
# ['10-251-8-Colada_de_Navalrincon']
# ['10-252-11-Sierra_de_Castellar_de_los_Bueyes']
# ['10-253-Todoterreno3-Retuerta_del_Bullaque']
# ['10-254-4-El_Chorro_Chorrera_chica_y_Rocigalgo']
# ['10-255-12-Robledal-Alcornocal']
# ['10-257-15-Camino_area_recreativa_del_Acebo_y_las_Fuentes', 'Ramales']
# ['10-260-16-La_Encina']
# ['10-261-14-Valle_del_Alcornocal']
# ['10-262-Todoterreno2-Horcajo_de_los_Montes']
# ['10-263-Todoterreno1-Alcoba_a_Casa_Palillos', 'Ramales']
# ['10-264-1-Senda_de_la_Torre_de_Abraham']
# ['10-265-9-Senda_botanica_en_el_entorno_del_centro_de_visitantes_de_Casa_Palillos', 'Ramales']
# ['10-266-13-Valhondo']
# ['10-341-6-La_Vinuela']
# ['10-342-7-Senda_de_la_Canada_Real_Segoviana']
# ['10-343-10-Senda_etnografica_en_el_entorno_del_centro_de_visitantes_de_Casa_Palillos']
# ['11-240-PRPND2-La_Rocina']
# ['11-241-PRPND10-Norte_del_Parque_Nacional']
# ['11-242-PRPND3-Palacio_del_Acebron']
# ['11-243-PRPND7-Sendero_Dunar']
# ['11-244-PRPND8-Recorrido_por_el_Interior_de_Donana']
# ['11-245-PRPND9-Fluvial_de_Sanlucar_a_Donana', 'Ramales']
# ['11-246-PRPND1-El_Acebuche', 'Ramales']
# ['12-268-PRPNIAGO3-Ruta_Norte_Isla_de_Ons']
# ['12-269-PRPNIAGO2-Ruta_del_Faro_Isla_de_Ons']
# ['12-270-PRPNIAGC6-Ruta_del_Faro_da_Porta_Islas_Cies']
# ['12-271-PRPNIAGO1-Ruta_Sur_Isla_de_Ons']
# ['12-272-PRPNIAGS1-Ruta_del_Faro']
# ['12-273-PRPNIAGC3-Ruta_del_Alto_do_Principe_Islas_Cies']
# ['12-274-PRPNIAGO4-Ruta_do_Castelo_Isla_de_Ons']
# ['12-275-PRPNIAGC1-Ruta_del_Monte_Faro_Islas_Cies']
# ['12-276-PRPNIAGS2-Ruta_de_la_Aldea']
# ['12-277-PRPNIAGC2-Ruta_del_sendero_Interior_Ruta_B']
# ['12-278-PRPNIAGC1-Ruta_del_sendero_Perimetral_Ruta_A']
# ['12-279-PRPNIAGC4-Ruta_de_Monteagudo_Islas_Cies', 'Ramales']
# ['13-211-SPN18-Jerez_del_Marquesado-Refugio_Postero_Alto_PR-A-31']
# ['13-212-GR240-El_Sendero_Sulayr_GR-240']
# ['13-213-SPN12-Senda_Monterrey_PR-A-25']
# ['13-214-SPN17-Puerto_de_la_Ragua-Aldeire_PR-A-333']
# ['13-215-SPN4-Silleta_de_Padul_PR-A-73']
# ['13-216-SPN9-Hoya_del_Portillo-Refugio_Poqueira_PR-A-26']
# ['13-217-SPN19-Rio_Alhama_PR-A-33']
# ['13-218-SPN16-Puerto_de_la_Ragua-Lagunilla_Seca_PR-A-334']
# ['13-219-SPN6-Pueblos_del_Poqueira_PR-A-70']
# ['13-220-SPN8-Acequias_del_Poqueira_PR-A-23']
# ['13-221-SPN5-Lanjaron-Tello_PR-A-34']
# ['13-222-SPN10-Trevelez-Siete_Lagunas_PR-A-27']
# ['13-223-SPN2-Cerro_Huenes_PR-A-20']
# ['13-224-SPN11-Rio_Grande_de_los_Berchules_PR-A-28']
# ['13-225-SPN1-Dornajo-Campos_de_Otero_PR-A-19']
# ['13-226-SPN13-El_Aguadero_PR-A-37']
# ['13-227-SPN3-Canal_de_la_Espartera-Arenales_del_Trevenque_PR-A-21']
# ['13-229-SPN7-Capileira-La_Cebadilla_PR-A-69']
# ['13-438-SPN14-Ubeire']
# ['13-439-SPN15-Molinos_de_Isfalada']
# ['14-280-Excursion3-Torre_de_Prado_Ancho_Ruta_Azul']
# ['14-281-Excursion4-Molino_de_Molemocho_Ruta_Magenta']
# ['14-282-Excursion2-La_Isla_del_Pan_Ruta_Amarilla', 'Ramales']
# ['14-283-Excursion1-La_Laguna_Permanente_Ruta_Roja']
# ['15-232-Excursion6-Visita_arqueologica', 'Ramales']
# ['15-233-Excursion8-El_Castillo']
# ['15-234-Excursion1-Ses_Sitges']
# ['15-235-Excursion7-Ruta_del_faro_de_l’Enciola']
# No se encontró una capa coincidente en C:\Users\maria.b.calvo\Documents\Personal\Hackathon GenAI\hackathon-repo\Hackathon-PNAV\Datos\Datos Rutas\Rutas Parques Naturales\015-Archipielago_de_Cabrera\15-235-Excursion7-Ruta_del_faro_de_lEnciola.kml, usando la primera disponible.
# ['15-236-Excursion3-Sierra_del_Canal_de_Ses_Figueres']
# ['15-237-Excursion2-Na_Picamosques']
# ['15-238-Excursion5-Ruta_del_museo_jardin_botanico_y_monumento_a_los_franceses']
# ['15-239-Excursion4-La_Miranda']
# ['16-404-SPN1-Caucon-Penon_de_los_Enamorados', 'Ramales']
# ['16-405-SPN2-Caucon-Tajo_de_la_Caina']
# ['16-406-SPN3-El_Burgo-Puerto_de_la_Mujer']
# ['16-407-SPN4-La_Rejia']
# ['16-408-SPN5-Las_Escaleretas', 'Ramales']
# ['16-409-SPN6-Puerto_Saucillo-Puerto_Bellina']
# ['16-410-SPN7-PR-A-351_Puerto_Saucillo-Torrecilla']
# ['16-411-SPN8-SL-A-140_Quejigales-Torrecilla']
# ['16-413-SPN9-SL-A-141_Yunquera-Los_Sauces']
# ['16-414-SPN10-PR-A-280_Istan-Charco_del_Canalon']
# ['16-415-SPN11-SL-A-239_Charco_de_la_Virgen']
# ['16-416-Ruta_turistica_Puerta_Verde_de_Marbella-Ronda']
# ['16-417-GR-243_Sierra_de_las_Nieves_Etapa_Ronda-El_Burgo']
# ['16-418-GR-243_Sierra_de_las_Nieves_Etapa_El_Burgo-Los_Sauces-Yunquera']
# ['16-419-GR-243_Sierra_de_las_Nieves_Etapa_Yunquera-Tolox']
# ['16-420-GR-243_Sierra_de_las_Nieves_Etapa_Tolox-Guaro']
# ['16-421-GR-243_Sierra_de_las_Nieves_Etapa_Guaro-Monda']
# ['16-422-GR-243_Sierra_de_las_Nieves_Etapa_Monda-Istan', 'Ramales']
# ['16-423-SZP1-Conejeras']
# ['16-424-SZP2-El_Burgo-La_Fuensanta']
# ['16-425-SZP3-PR-A-135_Istan-La_Concha']
# ['16-426-SZP4-PR-A-166_Istan-Herrizas_de_la_Gallega']
# ['16-427-SZP5-PR-A-167_Istan-Ojen']
# ['16-428-SZP6-PR-A-168_Juanar-La_Concha']
# ['16-429-SZP7-PR-A-278_Juanar-El_Pozuelo']
# ['16-430-SZP8-SL-A-228_Cruz_del_Padre_Ventura']
# ['16-431-SZP9-SL-A-229_Rio_de_los_Horcajos']
# ['16-432-SZP10-SL-A-246_Yunquera-Nacimiento_de_Rio_Grande']
# ['16-433-GR-243-1_Sierra_de_las_Nieves_Etapa_Ojen-Istan']
# ['3-284-Excursion1-Litoral', 'Ramales']
# ['3-285-Excursion3-Ruta_de_los_Volcanes']
# ['3-286-OS2-Subida_a_la_Caldera_de_Montana_Blanca']
# ['3-287-OS3-El_Grifo-Tinguaton']
# ['3-288-La_Costa_a_La_Santa']
# ['3-289-OS1-Mancha_Blanca-Playa_de_la_Madera']
# ['3-290-Miradero_a_Las_Malvas']
# ['3-291-OS4-Montana_del_Rodeo']
# ['3-292-Excursion2-Termesana']
# ['3-293-Teneza_a_la_Playa_del_Reisado']
# ['4-110-SPN23-Los_Regatones_Negros']
# ['4-111-SPN32-Abeque']
# ['4-112-SPN17-Igueque']
# ['4-113-SPN31-Cumbres_de_Ucanca', 'Ramales']
# ['4-114-SPN25-Recibo_Quemado']
# ['4-115-SPN12-Mirador_de_Pico_Viejo']
# ['4-116-SPN30-Los_Valles']
# ['4-117-SPN13-Samara', 'Ramales']
# ['4-118-SPN7-Montana_Blanca-La_Rambleta', 'Ramales']
# ['4-119-SPN6-Montana_de_los_Tomillos']
# ['4-120-SPN4-Siete_Canadas', 'Ramales']
# ['4-121-SPN14-Alto_de_Guamaso']
# ['4-122-SPN15-Alto_de_Guajara', 'Ramales']
# ['4-123-SPN3-Roques_de_Garcia']
# ['4-124-SPN5-Degollada_de_Guajara']
# ['4-125-SPN19-Majua']
# ['4-126-SPN8-El_Filo']
# ['4-127-SPN35-Boca_de_Chavao']
# ['4-128-SPN36-Alto_de_La_Fortaleza', 'Ramales']
# ['4-129-SPN33-Montana_Negra']
# ['4-130-SPN29-Degollada_del_Cedro']
# ['4-131-SPN9-Teide-Pico_Viejo-Mirador_de_las_Narices_del_Teide', 'Ramales']
# ['4-132-SPN18-Chavao']
# ['4-133-SPN22-Lomo_Hurtado']
# ['4-134-SPN34-Montana_Limon']
# ['4-135-SPN1-La_Fortaleza']
# ['4-136-SPN16-Sanatorio']
# ['4-137-SPN21-Corral_del_Nino-Yegua_Blanca']
# ['4-138-SPN11-Mirador_de_La_Fortaleza']
# ['4-139-SPN2-Arenas_Negras']
# ['4-140-SPN24-Portillo_Alto']
# ['4-141-SPN10-Telesforo_Bravo']
# ['4-142-SPN27-Montana_Rajada']
# ['4-143-SPN20-Volcan_de_Fasnia']
# ['4-145-SPN28-Chafari']
# ['4-146-SPN26-Ucanca']
# ['4-334-SPN37-El_Cerrillar-La_Carniceria']
# ['4-335-SPN38-Cuevas_Negras']
# ['4-338-SPN39-Teleferico-Montana_Blanca-Minas_de_San_Jose']
# ['4-339-SPN40-Llano_de_Ucanca-Boca_Tauce']
# ['4-340-SPN41-Barranco_de_Erques']
# ['4-388-SPN2-SPN40-Enlace_Chafari_-_Boca_Tauce']
# ['4-389-SPN24-SPN1-Enlace_Portillo_Alto_-_Jardin_Botanico_de_El_Portillo']
# ['5-33-Excursion5-Las_Creces']
# ['5-34-Pajarito_al_Ajugal']
# ['5-35-Excursion10-La_Laguna_Grande_I']
# ['5-36-Raso_Bruma_a_Risquillos']
# ['5-37-Excursion12-La_Meseta_de_Hermigua-El_Cedro']
# ['5-38-Excursion1-El_Bailadero']
# ['5-39-Pajarito_al_Alto_de_Garajonay']
# ['5-40-Excursion9-Canada_de_Jorge']
# ['5-41-La_Meseta_de_Hermigua_Las_tres_Cascadas']
# ['5-42-Excursion8-Reventon_Oscuro_a_El_Cedro']
# ['5-43-Agando_a_Casa_del_Manco']
# ['5-44-Excursion3-Subida_al_Alto_de_Garajonay']
# ['5-45-Pajarito_al_Chorro_del_Cedro']
# ['5-46-Excursion4-Laguna_Grande-Alto_de_Garajonay']
# ['5-47-Excursion13-Ermita_de_Lourdes']
# ['5-48-Excursion6-Los_Barranquillos']
# ['5-49-Excursion2-El_Contadero-El_Cedro']
# ['5-50-Excursion11-La_Laguna_Grande_II']
# ['6-1-RAM_PRPNPE19-Canal_de_Camburero', 'Ramales']
# ['6-10-PRPNPE24-Puertos_de_Aliva']
# ['6-11-PRPNPE27-Brez-Canal_de_las_Arredondas']
# ['6-12-GR202-Ruta_de_la_Reconquista']
# ['6-13-PRPNPE11-Panderruedas-Posada_de_Valdeon']
# ['6-14-PRPNPE1-Ruta_de_Frassinelli']
# ['6-15-PRPNPE17-Entorno_de_Tresviso']
# ['6-16-PRPNPE10-Pueblos_de_Sajambre', 'Ramales']
# ['6-17-PRPNPE15-Senda_del_Mercadillo', 'Ramales']
# ['6-18-PRPNPE8-Demues-Los_Lagos', 'Ramales']
# ['6-19-PRPNPE13-Cueva_de_Santibanas_Ruta_larga', 'Ramales']
# ['6-2-PRPNPE5-Vegarredonda-Ordiales']
# ['6-21-GR201-Senda_del_Arcediano', 'Ramales']
# ['6-22-PRPNPE23-Horcados_Rojos', 'Ramales']
# ['6-23-PRPNPE7-La_Jocica-Carombo']
# ['6-24-PRPNPE20-Monte_Camba_Tielve-Sotres']
# ['6-25-RAM_PRPNPE18-Jou_de_los_Cabrones']
# ['6-26-PRPNPE14-Monto_Valle_de_Prada', 'Ramales']
# ['6-27-PRPNPE25-Vega_de_Liordes']
# ['6-28-PRPNPE2-Ruta_de_los_Lagos', 'Ramales']
# ['6-29-PRPNPE4-Vega_de_Ario']
# ['6-3-RAM_PRPNPE16-Cordinanes-Collado_Jermoso', 'Ramales']
# ['6-30-PRPNPE9-Soto-Vegabano']
# ['6-31-PRPNPE30-Urdon-Tresviso']
# ['6-319-PRPNPE31-Camarmena']
# ['6-32-PRPNPE6-Orandi']
# ['6-320-PRPNPE32-Pandetrave-Collado_Jermoso']
# ['6-321-PRPNPE33-Oseja_de_Sajambre-Panderruedas']
# ['6-322-PRPNPE34-Sierra_de_Cocon_Oceno-San_Esteban']
# ['6-323-TRAV1-Refugio_de_Vega_de_Ario-Refugio_de_Vegarredonda']
# ['6-324-TRAV2-Refugio_de_Vegarredonda-Refugio_de_Vegabano']
# ['6-325-TRAV3-Refugio_de_Vega_de_Ario-Cain_por_Canal_de_Trea']
# ['6-326-TRAV4-Refugio_de_Vegarredonda-Cain_por_la_Canal_de_Mesones']
# ['6-327-TRAV5-Refugio_de_Vega_de_Urriellu-Refugio_del_Jou_de_los_Cabrones']
# ['6-328-TRAV6-El_Cable-Refugio_de_Vega_de_Urriellu', 'Ramales']
# ['6-329-TRAV7-Refugio_de_Vega_de_Urriellu-Refugio_de_Collado_Jermoso_Por_Tiro_Callejo', 'Ramales']
# ['6-330-TRAV9-Refugio_de_Andara-Canal_de_San_Carlos-Arguebanes', 'Ramales']
# ['6-331-TRAV8-El_Cable-Vega_de_Liordes', 'Ramales']
# ['6-336-PRPNPE07-PRPNPE09-Enlace_La_Jocica-Carombo_-_Soto-Vegabano']
# ['6-394-PRPNPE20-PRPNPE28-Enlace_Monte_Camba_Tielve-Sotres_-_Macizo_de_Andara']
# ['6-395-PRPNPE9-GR201-Enlace_Soto-Vegabano_-_Senda_del_Arcediano']
# ['6-396-TRAV2-PRPNPE12-Enlace_Refugio_de_Vegarredonda-Refugio_de_Vegabano_-_Vega_de_Llos']
# ['6-399-PRPNPE35-La_Farfada']
# ['6-4-PRPNPE3-Ruta_del_Cares']
# ['6-400-PRPNPE13-Cueva_de_Santibanas_Ruta_corta']
# ['6-401-PRPNPE34-Sierra_de_Cocon_Oceno-Tresviso']
# ['6-402-TRAV7-Refugio_de_Vega_de_Urriellu-Refugio_de_Collado_Jermoso_Por_Tiro_Casares']
# ['6-5-PRPNPE22-Pena_Oviedo_El_Cable-Mogrovejo']
# ['6-6-PRPNPE12-Vega_de_Llos']
# ['6-7-PRPNPE26-Hayedo_de_Las_Ilces']
# ['6-8-PRPNPE21-Vega_de_Urriellu']
# ['6-9-PRPNPE28-Macizo_de_Andara', 'Ramales']
# ['7-163-Los_Valles_de_Conangles_y_Rius']
# ['7-164-PRPNSN5-Camino_de_Sant_Maurici_al_Portarro_dEspot']
# ['7-165-PRPNSN3-Hacia_las_Agulles_d’Amitges']
# No se encontró una capa coincidente en C:\Users\maria.b.calvo\Documents\Personal\Hackathon GenAI\hackathon-repo\Hackathon-PNAV\Datos\Datos Rutas\Rutas Parques Naturales\07-Aiguestortes_i_Estany_de_Sant_Maurici\7-165-PRPNSN3-Hacia_las_Agulles_dAmitges.kml, usando la primera disponible.
# ['7-167-PRPNSN11-Camino_del_Estany_Llong_y_el_Portarro_dEspot', 'Ramales']
# ['7-168-Camino_al_Estany_de_Sant_Maurici']
# ['7-169-PRPNSN10-Circuito_de_Aiguestortes']
# ['7-170-PRPNSN8-Un_valle_colgado_Gerber']
# ['7-171-Los_Estanys_Gemena']
# ['7-172-PRPNSN7-Ruta_de_los_abetos_La_Mata_y_El_Gerdar']
# ['7-173-PRPNSN20-El_Gran_Circ_de_Colomers']
# ['7-174-PRPNSN18-El_Clot_de_la_Mainera']
# ['7-175-PRPNSN14-Hacia_los_Estanys_del_Pesso']
# ['7-176-PRPNASM2-La_Vall_de_Monestero']
# ['7-177-PRPNSN4-El_mirador_del_Estany_de_Sant_Maurici']
# ['7-178-A_caballo_de_las_montanas']
# ['7-312-Cascada_de_Gerber']
# ['7-313-PRPNSN9-Ruta_de_la_Nutria_Lludriga_hacia_Llebreta_y_Aiguestortes', 'Ramales']
# ['7-314-Camino_de_Rus']
# ['7-315-El_Valle_del_Estany_Tort']
# ['7-316-Camino_del_Estany_Saburo']
# ['7-317-El_Valle_de_Besiberri']
# ['7-318-PRPNSN25-Travesia_de_los_Refugios', 'Ramales']
# ['7-337-PRPNSN12-Ruta_de_la_Marmota_hacia_el_Estany_Negre']
# ['7-398-PRPNSN12-PRPNSN25-Enlace_Ruta_de_la_Marmota_-_Travesia_de_los_Refugios']
# ['8-434-SPN5-Ruta_Azul_Villarreal_de_San_Carlos_a_Malpartida_de_Plasencia']
# ['8-435-SPN6-Ruta_Negra_Camino_de_Barbaon']
# ['8-436-SPN7-Ruta_a_Toril_y_Serrejon']
# ['8-437-SPN8-Ruta_Marron_Camino_vecinal_a_Serradilla']
# ['8-51-SPN2-Ruta_Amarilla_Mirador_de_El_Serrano-Tajadilla']
# ['8-52-SPN4-Ruta_Morada_Villarreal_de_San_Carlos_a_Torrejon_el_Rubio']
# ['8-53-SPN1-Ruta_Verde_Arroyo_Malvecino-Cerro_Gimio', 'Ramales']
# ['8-54-SPN3-Ruta_Roja_Villarreal_de_San_Carlos-Castillo_de_Monfrague', 'Ramales']

# %%
# Unificar todos los GeoDataFrames manteniendo todas las columnas (rellenando valores faltantes con NaN)
gdf_unificado = gpd.GeoDataFrame(pd.concat(gdf_list, ignore_index=True, join='outer'))

# Crear una columna de ID con un rango de números
gdf_unificado['ID_Ruta'] = range(len(gdf_unificado))

# Ver las primeras filas para comprobar que todo está correcto
gdf_unificado.head()
# Out:
#       ID                        NOM_CAMINO          TIPOLOGIA  \
# 0  778.0  Camino Natural de Anaga - Chasna  CN por etapas (5)
# 1  779.0  Camino Natural de Anaga - Chasna  CN por etapas (5)
# 2  780.0  Camino Natural de Anaga - Chasna  CN por etapas (5)
# 3  781.0  Camino Natural de Anaga - Chasna  CN por etapas (5)
# 4  782.0  Camino Natural de Anaga - Chasna  CN por etapas (5)
#
#                                            NOM_ETAPA   LONGITUD ETAPA  \
# 0                 Etapa 1: La Esperanza - La Caldera  30.924081     1
# 1                  Etapa 2: La Caldera - El Portillo  14.171262     2
# 2  Etapa 3: El Portillo - Parador de Las Cañadas ...  16.686617     3
# 3  Etapa 4: Parador de Las Cañadas del Teide - Vi...  15.420307     4
# 4                          Etapa 5: Vilaflor - Arona  18.017360     5
#
#        CCAA               PROVINCIA HUSO  ID_SECTOR  ...  longitud fecha_edi  \
# 0  Canarias  Santa Cruz de Tenerife   28        7.0  ...       NaN       NaN
# 1  Canarias  Santa Cruz de Tenerife   28        7.0  ...       NaN       NaN
# 2  Canarias  Santa Cruz de Tenerife   28        7.0  ...       NaN       NaN
# 3  Canarias  Santa Cruz de Tenerife   28        7.0  ...       NaN       NaN
# 4  Canarias  Santa Cruz de Tenerife   28        7.0  ...       NaN       NaN
#
#   recorrido  provincia  comunidad estado  firme  nombre_en fecha_edit ID_Ruta
# 0       NaN        NaN        NaN    NaN    NaN        NaN        NaN       0
# 1       NaN        NaN        NaN    NaN    NaN        NaN        NaN       1
# 2       NaN        NaN        NaN    NaN    NaN        NaN        NaN       2
# 3       NaN        NaN        NaN    NaN    NaN        NaN        NaN       3
# 4       NaN        NaN        NaN    NaN    NaN        NaN        NaN       4
#
# [5 rows x 34 columns]

# %%
# Definir la ruta de salida
ruta_salida = os.path.join(carpeta_principal, "archivo_unificado.shp")

# Guardar el GeoDataFrame en un archivo SHP
gdf_unificado.to_file(ruta_salida)

print(f"Archivo unificado guardado en: {ruta_salida}")
# Out:
# C:\Users\maria.b.calvo\AppData\Local\Temp\ipykernel_6716\10481967.py:5: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_unificado.to_file(ruta_salida)
# Archivo unificado guardado en: C:\Users\maria.b.calvo\Documents\Personal\Hackathon GenAI\hackathon-repo\Hackathon-PNAV\Datos\Datos Rutas\archivo_unificado.shp
# C:\Users\maria.b.calvo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Description' to 'Descriptio'
#   ogr_write(
# C:\Users\maria.b.calvo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'id' to 'id_1'
#   ogr_write(
# C:\Users\maria.b.calvo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'longitud' to 'longitud_1'
#   ogr_write(
# C:\Users\maria.b.calvo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'provincia' to 'provinci_1'
#   ogr_write(
# C:\Users\maria.b.calvo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value '<center><table><tr><th colspan='2' align='center'><em>Atributos</em></th></tr><tr bgcolor="#E3E3F3"> <th>Parque Nacional</th> <td>Ordesa y Monte Perdido</td> </tr><tr bgcolor=""> <th>Nombre</th> <td>SA Monte Perdido</td> </tr><tr bgcolor="#E3E3F3"> <th>Número</th> <td>SA23</td> </tr><tr bgcolor=""> <th>Tipo</th> <td>Principal</td> </tr><tr bgcolor="#E3E3F3"> <th>Sentido</th> <td>Ida y vuelta</td> </tr><tr bgcolor=""> <th>Dificultad</th> <td>Alta</td> </tr><tr bgcolor="#E3E3F3"> <th>Duración (h)</th> <td>7.5</td> </tr><tr bgcolor=""> <th>Longitud (km)</th> <td>8.6</td> </tr><tr bgcolor="#E3E3F3"> <th>Recomendaciones</th> <td>Dificultad Media-Alta. Estamos ante una ruta de alta montaña, lo que exige preparación, planificación y equipamiento adecuados. Hay que prever la posible presencia de nieve en algún tramo de la parte más alta. En el ascenso, no hay que perder de vista los mojones que nos señalan el mejor camino entre las sendas marcadas. Sin nieve, poco antes de llegar al lago Helado está el pequeño paso de la Rimaya, que puede ser resbaladizo, equipado con cadenas pasamanos para evitar caídas. Extremaremos las precauciones en el peligroso paso de La Escupidera, que con nieve obliga a usar crampones y piolet. Preste atención a las vistas sobre el valle de Ordesa y las imponentes cimas de las tres Sorores, el Cilindro de Marboré, el Monte Perdido y el pico Añisclo. El ibón Helado, uno de los lagos más elevados del Pirineo. La panorámica que ofrece la cima.</td> </tr><tr bgcolor=""> <th>Descripción</th> <td>El sendero parte del refugio de Góriz, a 2.195 m de altitud, en dirección noreste por la margen izquierda del barranco. El camino, bien marcado, supera unos contrafuertes iniciales a través de una serie de zigzags. Pastizales y pedreras es el paisaje que encontramos en la ruta hasta que se adentra en un laberinto de grandes bloques de piedra. Aquí ponemos cuidado para no perder de vista los mojones que nos señalan el mejor camino entre las numerosas sendas marcadas. Superada esta zona, afrontamos un tramo de pedreras que nos lleva hasta el ibón Helado (2 horas 30 minutos, altitud de 2.988 m), lago ubicado a gran altura entre las cumbres del Cilindro de Marboré y el Monte Perdido. Dejamos atrás el ibón para girar a la derecha en dirección sureste y adentrarnos en la canal de fuerte pendiente que desciende desde la misma cima del Monte Perdido. Ponemos especial atención en el punto en el que el camino deja el resalte rocoso para adentrarse en la canal, lugar conocido como «La Escupidera» que resulta especialmente peligroso con presencia de nieve. Piolet y crampones son entonces obligatorios en este punto, aspecto que habremos tenido muy en cuenta antes de iniciar la excursión.  La canal concluye en un pequeño collado (3 horas 10 minutos, altitud 3.135 m), justo encima de los glaciares de la cara norte. Giramos a la derecha para alcanzar una pequeña elevación, la redondeada cima del Monte Perdido.</td> </tr></table></center>' of field Descriptio has been truncated to 254 characters.  This warning will not be emitted any more for that layer.
#   ogr_write(

# %%
# Imprimir nombres de las columnas (atributos)
print("Columnas del SHP:", gdf_unificado.columns)
# Out:
# Columnas del SHP: Index(['ID', 'NOM_CAMINO', 'TIPOLOGIA', 'NOM_ETAPA', 'LONGITUD', 'ETAPA',
#        'CCAA', 'PROVINCIA', 'HUSO', 'ID_SECTOR', 'ID_CAMINO', 'COD_CAMINO',
#        'ID_ETAPA', 'LONG_3D_GE', 'NUM_CAMINO', 'NOM_TOTAL', 'XCENTROIDE',
#        'YCENTROIDE', 'geometry', 'source', 'Name', 'Description', 'id',
#        'nombre', 'longitud', 'fecha_edi', 'recorrido', 'provincia',
#        'comunidad', 'estado', 'firme', 'nombre_en', 'fecha_edit', 'ID_Ruta'],
#       dtype='object')

# %%
gdf_atributos = gdf_unificado.copy()

# Diccionario de columnas equivalentes
column_mapping = {
    "Nombre_Ruta": ["NOM_CAMINO", "Name", "nombre"],
    "Longitud": ["LONGITUD", "longitud"],
    "Provincia": ["PROVINCIA", "provincia"],
    "CC_AA": ["CCAA", "comunidad"]
}

# Crear nuevas columnas con los valores existentes
for new_col, old_cols in column_mapping.items():
    gdf_atributos[new_col] = gdf_atributos[old_cols].bfill(axis=1).iloc[:, 0]  # Rellenar con el primer valor no nulo

# Eliminar las columnas antiguas si ya no se necesitan
columns_to_drop = sum(column_mapping.values(), [])  # Convertir listas de valores en una sola lista
gdf_atributos = gdf_atributos.drop(columns=columns_to_drop, errors="ignore")

# Imprimir nombres de las columnas (atributos)
print("Columnas del SHP:", gdf_atributos.columns)

# Crear una columna del nombre completo para aquellas rutas separadas por etapas
gdf_atributos['Nombre_completo'] = gdf_atributos['Nombre_Ruta'] + ' ' + gdf_atributos['NOM_ETAPA'].fillna('')

nuevo_orden = ['ID_Ruta', 'Nombre_Ruta', 'NOM_ETAPA', 'Nombre_completo', 'Longitud', 'Provincia', 'CC_AA', 
       'ID', 'TIPOLOGIA', 'ETAPA', 'HUSO', 'ID_SECTOR',
       'ID_CAMINO', 'COD_CAMINO', 'ID_ETAPA', 'LONG_3D_GE', 'NUM_CAMINO',
       'NOM_TOTAL', 'XCENTROIDE', 'YCENTROIDE', 'geometry', 'source',
       'Description', 'id', 'fecha_edi', 'recorrido', 'estado', 'firme',
       'nombre_en', 'fecha_edit']
gdf_atributos = gdf_atributos[nuevo_orden]

# Imprimir nombres de las columnas (atributos)
print("Columnas del SHP:", gdf_atributos.columns)
# Out:
# Columnas del SHP: Index(['ID', 'TIPOLOGIA', 'NOM_ETAPA', 'ETAPA', 'HUSO', 'ID_SECTOR',
#        'ID_CAMINO', 'COD_CAMINO', 'ID_ETAPA', 'LONG_3D_GE', 'NUM_CAMINO',
#        'NOM_TOTAL', 'XCENTROIDE', 'YCENTROIDE', 'geometry', 'source',
#        'Description', 'id', 'fecha_edi', 'recorrido', 'estado', 'firme',
#        'nombre_en', 'fecha_edit', 'ID_Ruta', 'Nombre_Ruta', 'Longitud',
#        'Provincia', 'CC_AA'],
#       dtype='object')
# Columnas del SHP: Index(['ID_Ruta', 'Nombre_Ruta', 'NOM_ETAPA', 'Nombre_completo', 'Longitud',
#        'Provincia', 'CC_AA', 'ID', 'TIPOLOGIA', 'ETAPA', 'HUSO', 'ID_SECTOR',
#        'ID_CAMINO', 'COD_CAMINO', 'ID_ETAPA', 'LONG_3D_GE', 'NUM_CAMINO',
#        'NOM_TOTAL', 'XCENTROIDE', 'YCENTROIDE', 'geometry', 'source',
#        'Description', 'id', 'fecha_edi', 'recorrido', 'estado', 'firme',
#        'nombre_en', 'fecha_edit'],
#       dtype='object')

# %%
# Definir la ruta de salida
ruta_salida = os.path.join(carpeta_principal, "archivo_atributos_unificados.shp")

# Guardar el GeoDataFrame en un archivo SHP
gdf_atributos.to_file(ruta_salida)
# Out:
# C:\Users\maria.b.calvo\AppData\Local\Temp\ipykernel_6716\918135260.py:5: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_atributos.to_file(ruta_salida)
# C:\Users\maria.b.calvo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Nombre_Ruta' to 'Nombre_Rut'
#   ogr_write(
# C:\Users\maria.b.calvo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Nombre_completo' to 'Nombre_com'
#   ogr_write(
# C:\Users\maria.b.calvo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'Description' to 'Descriptio'
#   ogr_write(
# C:\Users\maria.b.calvo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'id' to 'id_1'
#   ogr_write(
# C:\Users\maria.b.calvo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyogrio\raw.py:723: RuntimeWarning: Value '<center><table><tr><th colspan='2' align='center'><em>Atributos</em></th></tr><tr bgcolor="#E3E3F3"> <th>Parque Nacional</th> <td>Ordesa y Monte Perdido</td> </tr><tr bgcolor=""> <th>Nombre</th> <td>SA Monte Perdido</td> </tr><tr bgcolor="#E3E3F3"> <th>Número</th> <td>SA23</td> </tr><tr bgcolor=""> <th>Tipo</th> <td>Principal</td> </tr><tr bgcolor="#E3E3F3"> <th>Sentido</th> <td>Ida y vuelta</td> </tr><tr bgcolor=""> <th>Dificultad</th> <td>Alta</td> </tr><tr bgcolor="#E3E3F3"> <th>Duración (h)</th> <td>7.5</td> </tr><tr bgcolor=""> <th>Longitud (km)</th> <td>8.6</td> </tr><tr bgcolor="#E3E3F3"> <th>Recomendaciones</th> <td>Dificultad Media-Alta. Estamos ante una ruta de alta montaña, lo que exige preparación, planificación y equipamiento adecuados. Hay que prever la posible presencia de nieve en algún tramo de la parte más alta. En el ascenso, no hay que perder de vista los mojones que nos señalan el mejor camino entre las sendas marcadas. Sin nieve, poco antes de llegar al lago Helado está el pequeño paso de la Rimaya, que puede ser resbaladizo, equipado con cadenas pasamanos para evitar caídas. Extremaremos las precauciones en el peligroso paso de La Escupidera, que con nieve obliga a usar crampones y piolet. Preste atención a las vistas sobre el valle de Ordesa y las imponentes cimas de las tres Sorores, el Cilindro de Marboré, el Monte Perdido y el pico Añisclo. El ibón Helado, uno de los lagos más elevados del Pirineo. La panorámica que ofrece la cima.</td> </tr><tr bgcolor=""> <th>Descripción</th> <td>El sendero parte del refugio de Góriz, a 2.195 m de altitud, en dirección noreste por la margen izquierda del barranco. El camino, bien marcado, supera unos contrafuertes iniciales a través de una serie de zigzags. Pastizales y pedreras es el paisaje que encontramos en la ruta hasta que se adentra en un laberinto de grandes bloques de piedra. Aquí ponemos cuidado para no perder de vista los mojones que nos señalan el mejor camino entre las numerosas sendas marcadas. Superada esta zona, afrontamos un tramo de pedreras que nos lleva hasta el ibón Helado (2 horas 30 minutos, altitud de 2.988 m), lago ubicado a gran altura entre las cumbres del Cilindro de Marboré y el Monte Perdido. Dejamos atrás el ibón para girar a la derecha en dirección sureste y adentrarnos en la canal de fuerte pendiente que desciende desde la misma cima del Monte Perdido. Ponemos especial atención en el punto en el que el camino deja el resalte rocoso para adentrarse en la canal, lugar conocido como «La Escupidera» que resulta especialmente peligroso con presencia de nieve. Piolet y crampones son entonces obligatorios en este punto, aspecto que habremos tenido muy en cuenta antes de iniciar la excursión.  La canal concluye en un pequeño collado (3 horas 10 minutos, altitud 3.135 m), justo encima de los glaciares de la cara norte. Giramos a la derecha para alcanzar una pequeña elevación, la redondeada cima del Monte Perdido.</td> </tr></table></center>' of field Descriptio has been truncated to 254 characters.  This warning will not be emitted any more for that layer.
#   ogr_write(

# %%
# Definir la ruta de salida
ruta_salida = os.path.join(carpeta_principal, "archivo_rutas.csv")

# La longitud se expresa en decimales con punto decimal para evitar problemas con el formato CSV
gdf_atributos.to_csv(ruta_salida, index=False, encoding="utf-8-sig", decimal=",")

print("Archivo CSV creado con éxito.")
# Out:
# Archivo CSV creado con éxito.
